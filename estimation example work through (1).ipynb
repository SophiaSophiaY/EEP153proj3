# %%
# !pip install CFEDemands --upgrade

#uncomment if needed
#!pip install xarray
#!pip install dvc
#!pip install oauth2client

import xarray
import dvc
import oauth2client
# Out:
# Requirement already up-to-date: CFEDemands in /opt/conda/lib/python3.8/site-packages (0.2.7)

# %% [markdown]
# ### From Sheet to DataFrame to Result Object

# %%
ICRISAT_Data = '1z35Kyga40hhoGBEQIY9jReY6z1wmnsnlUVw-pFEaBhg' #key matches the url of the google docs link above

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../Project2/')
from eep153_tools import read_sheets

#### Need private keys from json file (we're authenticating using "service accounts")
# !gpg --batch --passphrase "noodle octopus" -d ../students-9093fa174318.json.gpg > ../students-9093fa174318.json
####

# Add credentials if sheet not meant to be public
x = read_sheets(ICRISAT_Data,sheet='Expenditures',json_creds='../students-9093fa174318.json')
                 
# Change 'ICRISAT' to key of your own sheet in Sheets, above
z = read_sheets(ICRISAT_Data,sheet="HH Characteristics",json_creds='../students-9093fa174318.json')

# Assume a single market: (Comment this out to make each village its own market)
z['m'] = 1
x['m'] = 1

x = x.replace(0,np.nan) # Replace zeros with missing

# Take logs of expenditures; call this y
y = np.log(x.set_index(['j','t','m']))

z.set_index(['j','t','m'],inplace=True)
# Out:
# gpg: AES256 encrypted data
# gpg: encrypted with 1 passphrase

# %%
z.head()
# Out:
#             Males 0-1  Males 1-5  Males 5-10  Males 10-15  Males 15-20  \
# j   t    m
# 100 2003 1          1          0           0            0            1
# 101 2003 1          0          0           2            1            0
# 102 2003 1          0          0           0            0            0
# 103 2003 1          0          1           1            2            1
# 105 2003 1          0          0           0            0            0
#
#             Males 20-30  Males 30-50  Males 50-60  Males 60-100  Females 0-1  \
# j   t    m
# 100 2003 1            0            0            1             0            0
# 101 2003 1            2            1            0             0            1
# 102 2003 1            1            1            0             1            0
# 103 2003 1            2            1            0             0            0
# 105 2003 1            3            2            0             1            0
#
#             Females 1-5  Females 5-10  Females 10-15  Females 15-20  \
# j   t    m
# 100 2003 1            0             0              1              1
# 101 2003 1            1             1              1              0
# 102 2003 1            0             0              0              0
# 103 2003 1            0             0              1              1
# 105 2003 1            0             0              1              0
#
#             Females 20-30  Females 30-50  Females 50-60  Females 60-100  \
# j   t    m
# 100 2003 1              0              1              0               0
# 101 2003 1              2              1              0               1
# 102 2003 1              1              1              1               0
# 103 2003 1              1              1              0               0
# 105 2003 1              0              3              0               1
#
#             log HSize
# j   t    m
# 100 2003 1   1.791759
# 101 2003 1   2.639057
# 102 2003 1   1.791759
# 103 2003 1   2.484907
# 105 2003 1   2.397895

# %%
z
# Out:
#             Males 0-1  Males 1-5  Males 5-10  Males 10-15  Males 15-20  \
# j   t    m
# 100 2003 1          1          0           0            0            1
# 101 2003 1          0          0           2            1            0
# 102 2003 1          0          0           0            0            0
# 103 2003 1          0          1           1            2            1
# 105 2003 1          0          0           0            0            0
# ...               ...        ...         ...          ...          ...
# 940 2003 1          0          0           1            0            0
# 941 2003 1          0          0           0            0            0
# 95  2003 1          0          0           0            1            2
# 96  2003 1          0          0           0            0            1
# 99  2003 1          0          0           0            1            0
#
#             Males 20-30  Males 30-50  Males 50-60  Males 60-100  Females 0-1  \
# j   t    m
# 100 2003 1            0            0            1             0            0
# 101 2003 1            2            1            0             0            1
# 102 2003 1            1            1            0             1            0
# 103 2003 1            2            1            0             0            0
# 105 2003 1            3            2            0             1            0
# ...                 ...          ...          ...           ...          ...
# 940 2003 1            0            1            0             0            0
# 941 2003 1            1            0            0             0            0
# 95  2003 1            1            1            1             0            0
# 96  2003 1            0            1            0             0            0
# 99  2003 1            2            0            1             0            0
#
#             Females 1-5  Females 5-10  Females 10-15  Females 15-20  \
# j   t    m
# 100 2003 1            0             0              1              1
# 101 2003 1            1             1              1              0
# 102 2003 1            0             0              0              0
# 103 2003 1            0             0              1              1
# 105 2003 1            0             0              1              0
# ...                 ...           ...            ...            ...
# 940 2003 1            0             0              1              0
# 941 2003 1            0             1              0              0
# 95  2003 1            0             0              0              0
# 96  2003 1            0             0              0              0
# 99  2003 1            0             0              1              1
#
#             Females 20-30  Females 30-50  Females 50-60  Females 60-100  \
# j   t    m
# 100 2003 1              0              1              0               0
# 101 2003 1              2              1              0               1
# 102 2003 1              1              1              1               0
# 103 2003 1              1              1              0               0
# 105 2003 1              0              3              0               1
# ...                   ...            ...            ...             ...
# 940 2003 1              0              1              0               0
# 941 2003 1              1              0              0               0
# 95  2003 1              0              0              1               0
# 96  2003 1              4              0              1               0
# 99  2003 1              0              1              0               0
#
#             log HSize
# j   t    m
# 100 2003 1   1.791759
# 101 2003 1   2.639057
# 102 2003 1   1.791759
# 103 2003 1   2.484907
# 105 2003 1   2.397895
# ...               ...
# 940 2003 1   1.386294
# 941 2003 1   1.098612
# 95  2003 1   1.945910
# 96  2003 1   1.945910
# 99  2003 1   1.945910
#
# [572 rows x 19 columns]

# %%
y.head()
# Out:
#            Alcoholic drinks  Alugbati  Ampalaya  Atis     Atsal   Bagoong  \
# j  t    m
# 2  2003 1               NaN       NaN       NaN   NaN       NaN       NaN
# 4  2003 1               NaN       NaN       NaN   NaN       NaN  2.890372
# 5  2003 1          3.091042       NaN       NaN   NaN       NaN -0.287682
# 6  2003 1               NaN       NaN  2.302585   NaN       NaN       NaN
# 12 2003 1               NaN       NaN  1.609438   NaN  1.832581       NaN
#
#            Bamboo shoots    Banana      Beef  Birds  ...  \
# j  t    m                                            ...
# 2  2003 1            NaN  3.688879  3.401197    NaN  ...
# 4  2003 1            NaN       NaN  3.314186    NaN  ...
# 5  2003 1            NaN       NaN       NaN    NaN  ...
# 6  2003 1            NaN       NaN  4.174387    NaN  ...
# 12 2003 1            NaN       NaN       NaN    NaN  ...
#
#            Soybean and other products    Squash     Sugar  Sweet potato  \
# j  t    m
# 2  2003 1                    2.302585  0.223144  3.258097           NaN
# 4  2003 1                    2.995732  1.609438  2.302585           NaN
# 5  2003 1                         NaN       NaN  0.916291           NaN
# 6  2003 1                    2.708050  0.916291  2.890372           NaN
# 12 2003 1                    1.945910       NaN  3.401197      3.044522
#
#              Talong  Tomatoes  Transfer of residence      Upo  Vetsin, MSG  \
# j  t    m
# 2  2003 1       NaN  1.609438                    NaN      NaN     1.609438
# 4  2003 1       NaN  2.302585                    NaN      NaN     2.302585
# 5  2003 1       NaN  1.791759                    NaN      NaN     1.609438
# 6  2003 1       NaN  2.302585                    NaN      NaN     0.223144
# 12 2003 1  2.302585  1.609438                    NaN  1.94591     2.995732
#
#             Vinegar
# j  t    m
# 2  2003 1  0.223144
# 4  2003 1  0.000000
# 5  2003 1  0.223144
# 6  2003 1       NaN
# 12 2003 1  1.609438
#
# [5 rows x 81 columns]

# %% [markdown]
# ## Estimation

# %%
import cfe

result = cfe.Result(y=y,z=z)

# %%
result
# Out:
# <xarray.Result>
# Dimensions:           (i: 42, j: 572, k: 19, m: 1, t: 1)
# Coordinates:
#   * j                 (j) int64 2 4 5 6 12 13 14 ... 935 936 937 938 939 940 941
#   * m                 (m) int64 1
#   * t                 (t) int64 2003
#   * i                 (i) <U45 'Alcoholic drinks' 'Ampalaya' ... 'Vinegar'
#   * k                 (k) <U14 'Males 0-1' 'Males 1-5' ... 'log HSize'
# Data variables:
#     alpha             object None
#     beta              object None
#     delta             object None
#     prices            object None
#     characteristics   (k, j, t, m) float64 0.0 0.0 0.0 0.0 ... 1.792 1.386 1.099
#     loglambdas        object None
#     a                 object None
#     yhat              object None
#     ce                object None
#     cehat             object None
#     e                 object None
#     delta_covariance  object None
#     beta_covariance   object None
#     se_delta          object None
#     se_beta           object None
#     se_alpha          object None
#     se_a              object None
#     y                 (i, j, m, t) float64 nan nan 3.091 ... -0.6931 1.946 2.996
#     logp              object None
#     z                 (k, j, t, m) float64 0.0 0.0 0.0 0.0 ... 1.792 1.386 1.099
# Attributes:
#     firstround:            2003
#     min_proportion_items:  0.125
#     min_xproducts:         30
#     useless_expenditures:  False
#     stderr_tol:            0.01
#     indices:               Indices(j='j', t='t', m='m', i='i', k='k')
#     verbose:               False

# %% [markdown]
# ### First step of Estimation

# %% [markdown]
# Estimating the &ldquo;reduced form&rdquo; linear regression
# $$
# y_{it}^j = {a}_{it} + \delta_i'{z}^j_t + \epsilon_{it}^j.
# $$
#
# The Result class has code to estimate this in one line and look at the estimated coefficients $\delta$:

# %%
result.get_reduced_form()
# Out:
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))
# /opt/conda/lib/python3.8/site-packages/cfe/estimation.py:367: UserWarning: No variation in: (2003, 1)
#   warnings.warn("No variation in: %s" % str(constant))

# %%
result.delta.to_dataframe().unstack('k')
# holding household size constant the numbers represent a percentage increase or decrease in household 
# expenditures of the item
# Out:
#                                                     delta              \
# k                                             Females 0-1 Females 1-5
# i
# Alcoholic drinks                                -0.229230   -0.026475
# Ampalaya                                        -0.310872    0.169819
# Atsal                                            0.246878   -0.093379
# Bagoong                                         -0.311432   -0.024882
# Banana                                           0.118409    0.072187
# Beef                                             0.066491   -0.009593
# Calamansi                                        0.186709    0.073960
# Carrots                                          0.037546    0.013946
# Chicken                                         -0.302186   -0.352860
# Coffee                                          -0.029142    0.002722
# Coke                                             0.014610   -0.012935
# Cooking oil                                      0.010259   -0.168674
# Corn products                                   -1.046075    0.223242
# Dried fish and smoked fish                      -0.139872   -0.129660
# Eggs                                             0.084261    0.029775
# Food made from flour                             0.016886    0.106308
# Fresh fish                                       0.036888    0.034519
# Milk                                             0.454836    0.413555
# Milo                                            -0.082501    0.040696
# Mongo and other products                        -0.000962   -0.017632
# Okra                                             0.001174    0.234017
# Onions                                          -0.009465    0.006071
# Other beverages                                 -0.222810   -0.096414
# Petsay                                          -0.423402    0.037326
# Pork                                            -0.208672    0.092542
# Potato                                          -0.294192   -0.157375
# Processed meat like longanisa                   -0.033387    0.159841
# Rice                                             0.207261    0.071451
# Rice products                                    0.027039    0.031765
# Salt                                             0.209363   -0.007914
# Sardines like youngstown, etc                    0.018615    0.070375
# Sea weed                                        -0.937852    0.049253
# Sitao                                            0.268862   -0.037764
# Snaks like chippy, cheese curls, bread sticks    0.076018   -0.059136
# Soybean and other products                       0.013037    0.054587
# Squash                                          -0.220856    0.171372
# Sugar                                           -0.116699    0.128147
# Sweet potato                                    -0.523729    0.100649
# Talong                                          -0.129571    0.241133
# Tomatoes                                         0.054085    0.016633
# Vetsin, MSG                                      0.156050    0.046791
# Vinegar                                         -0.021601   -0.045639
#
#                                                                            \
# k                                             Females 10-15 Females 15-20
# i
# Alcoholic drinks                                   0.081037     -0.104062
# Ampalaya                                           0.256434      0.188770
# Atsal                                             -0.007398     -0.032146
# Bagoong                                            0.038794      0.089662
# Banana                                             0.071651      0.102375
# Beef                                              -0.032711      0.098828
# Calamansi                                          0.207899     -0.020976
# Carrots                                           -0.036879      0.154457
# Chicken                                           -0.043431     -0.034519
# Coffee                                            -0.108671      0.234855
# Coke                                               0.144834      0.120036
# Cooking oil                                        0.059917     -0.024102
# Corn products                                     -0.327611     -0.199217
# Dried fish and smoked fish                         0.045447     -0.076852
# Eggs                                               0.051302      0.113746
# Food made from flour                               0.096750      0.154836
# Fresh fish                                        -0.004685     -0.013790
# Milk                                               0.100576     -0.039398
# Milo                                              -0.135233      0.084953
# Mongo and other products                           0.026332      0.001594
# Okra                                               0.227645      0.246633
# Onions                                             0.001290      0.080460
# Other beverages                                   -0.205357      0.165018
# Petsay                                             0.213658      0.224070
# Pork                                              -0.008691      0.059829
# Potato                                            -0.076116      0.198967
# Processed meat like longanisa                      0.290579     -0.005356
# Rice                                              -0.099437      0.018402
# Rice products                                      0.123941      0.078830
# Salt                                              -0.045819     -0.019829
# Sardines like youngstown, etc                      0.148090     -0.029719
# Sea weed                                          -0.191589     -0.222523
# Sitao                                              0.087772      0.024176
# Snaks like chippy, cheese curls, bread sticks     -0.165987     -0.258183
# Soybean and other products                         0.059768      0.096795
# Squash                                             0.159589      0.156439
# Sugar                                              0.092708      0.008982
# Sweet potato                                      -0.257844      0.232995
# Talong                                             0.112177      0.004387
# Tomatoes                                           0.155549      0.080458
# Vetsin, MSG                                       -0.032689      0.089343
# Vinegar                                           -0.082469      0.039738
#
#                                                                            \
# k                                             Females 20-30 Females 30-50
# i
# Alcoholic drinks                                   0.026543     -0.004507
# Ampalaya                                           0.122040      0.153541
# Atsal                                              0.112279      0.110263
# Bagoong                                           -0.124982      0.018533
# Banana                                             0.102706      0.283883
# Beef                                               0.000930      0.039877
# Calamansi                                          0.096720      0.202463
# Carrots                                            0.065406      0.358634
# Chicken                                            0.102761      0.047744
# Coffee                                             0.108909      0.100694
# Coke                                               0.028302      0.042655
# Cooking oil                                        0.130711      0.175318
# Corn products                                     -0.170933     -0.008646
# Dried fish and smoked fish                         0.052928     -0.069217
# Eggs                                               0.132489      0.117657
# Food made from flour                               0.013777      0.157283
# Fresh fish                                         0.048533      0.149077
# Milk                                              -0.010409      0.166154
# Milo                                               0.046229      0.141296
# Mongo and other products                          -0.012467     -0.007284
# Okra                                               0.172970      0.279927
# Onions                                             0.118443      0.143537
# Other beverages                                   -0.155458      0.208093
# Petsay                                             0.068004      0.018270
# Pork                                               0.058585      0.013765
# Potato                                             0.130239      0.045855
# Processed meat like longanisa                      0.070477      0.090899
# Rice                                              -0.026816      0.034771
# Rice products                                      0.073873      0.058721
# Salt                                              -0.033529      0.005425
# Sardines like youngstown, etc                     -0.037364     -0.029204
# Sea weed                                           0.049303      0.157836
# Sitao                                              0.069952      0.111108
# Snaks like chippy, cheese curls, bread sticks     -0.112061     -0.020843
# Soybean and other products                         0.184506      0.217554
# Squash                                             0.165964      0.199056
# Sugar                                              0.088265      0.114538
# Sweet potato                                       0.013477      0.143152
# Talong                                             0.154340      0.057803
# Tomatoes                                           0.092882      0.107513
# Vetsin, MSG                                        0.100211      0.077319
# Vinegar                                            0.087920      0.066908
#
#                                                                           \
# k                                             Females 5-10 Females 50-60
# i
# Alcoholic drinks                                 -0.074601      0.022786
# Ampalaya                                          0.301018      0.192354
# Atsal                                             0.459638      0.071584
# Bagoong                                           0.150319      0.017961
# Banana                                            0.272715      0.281669
# Beef                                              0.013613     -0.243199
# Calamansi                                         0.040012      0.443007
# Carrots                                          -0.150419      0.372103
# Chicken                                           0.132334      0.168608
# Coffee                                            0.226842      0.296630
# Coke                                              0.108870      0.234966
# Cooking oil                                       0.036555      0.196961
# Corn products                                    -0.067413     -0.320316
# Dried fish and smoked fish                        0.041801     -0.050495
# Eggs                                              0.206686      0.228364
# Food made from flour                              0.282267      0.175060
# Fresh fish                                        0.069885      0.251045
# Milk                                              0.033264      0.179868
# Milo                                              0.189363      0.374928
# Mongo and other products                         -0.048607      0.315521
# Okra                                              0.010904      0.088307
# Onions                                            0.114630      0.088179
# Other beverages                                  -0.186988     -0.311785
# Petsay                                            0.136180      0.108419
# Pork                                             -0.038674     -0.190291
# Potato                                            0.401256      0.289265
# Processed meat like longanisa                     0.146651      0.268029
# Rice                                              0.145068     -0.103977
# Rice products                                     0.080147      0.183933
# Salt                                              0.149063      0.061962
# Sardines like youngstown, etc                     0.113052     -0.024961
# Sea weed                                          0.027932      0.075260
# Sitao                                             0.146250      0.121781
# Snaks like chippy, cheese curls, bread sticks     0.107435      0.048855
# Soybean and other products                        0.112457      0.050305
# Squash                                            0.210821      0.204360
# Sugar                                             0.172528      0.071761
# Sweet potato                                      0.187842     -0.122418
# Talong                                            0.107079      0.015835
# Tomatoes                                          0.097083      0.233818
# Vetsin, MSG                                       0.037902      0.116608
# Vinegar                                           0.087232     -0.079365
#
#                                                                         \
# k                                             Females 60-100 Males 0-1
# i
# Alcoholic drinks                                    0.102631  0.197734
# Ampalaya                                            0.383562  0.040922
# Atsal                                              -0.003891  0.222673
# Bagoong                                            -0.181675 -0.055391
# Banana                                              0.253598  0.278559
# Beef                                               -0.138555  0.244980
# Calamansi                                           0.053786 -0.126752
# Carrots                                             0.032209  0.183419
# Chicken                                             0.347631  0.018365
# Coffee                                             -0.176597 -0.070132
# Coke                                               -0.034586  0.105533
# Cooking oil                                        -0.176390 -0.098209
# Corn products                                      -0.418025  0.082699
# Dried fish and smoked fish                         -0.079231 -0.221290
# Eggs                                                0.084131  0.019769
# Food made from flour                               -0.060726  0.408036
# Fresh fish                                         -0.199395  0.129576
# Milk                                                0.047118  0.820564
# Milo                                                0.050108  0.467001
# Mongo and other products                           -0.218276 -0.002811
# Okra                                               -0.085450 -0.175372
# Onions                                              0.048892 -0.055077
# Other beverages                                    -0.012546 -0.132743
# Petsay                                             -0.052366  0.020003
# Pork                                               -0.137820 -0.025122
# Potato                                              0.242072  0.006234
# Processed meat like longanisa                       0.049508  0.431187
# Rice                                                0.094810 -0.062130
# Rice products                                      -0.121114  0.057465
# Salt                                               -0.156218  0.057618
# Sardines like youngstown, etc                      -0.221392  0.020258
# Sea weed                                           -0.025967  0.413241
# Sitao                                              -0.082479 -0.025254
# Snaks like chippy, cheese curls, bread sticks      -0.397660  0.217309
# Soybean and other products                         -0.034068 -0.037239
# Squash                                              0.079451  0.294856
# Sugar                                              -0.126867  0.132379
# Sweet potato                                        0.405980 -0.002968
# Talong                                              0.099231 -0.413523
# Tomatoes                                            0.107759 -0.041397
# Vetsin, MSG                                        -0.213277 -0.042219
# Vinegar                                            -0.014262  0.131874
#
#                                                                      \
# k                                             Males 1-5 Males 10-15
# i
# Alcoholic drinks                              -0.035662   -0.238435
# Ampalaya                                       0.260205    0.239278
# Atsal                                          0.130434    0.012965
# Bagoong                                        0.090373    0.022504
# Banana                                         0.272695    0.316267
# Beef                                           0.050033    0.088629
# Calamansi                                      0.000233    0.200694
# Carrots                                        0.165941   -0.163690
# Chicken                                        0.035918   -0.143412
# Coffee                                         0.027453    0.155959
# Coke                                          -0.045090    0.098955
# Cooking oil                                    0.012178    0.061460
# Corn products                                  0.208973   -0.137925
# Dried fish and smoked fish                    -0.144569    0.128979
# Eggs                                           0.066225    0.102196
# Food made from flour                           0.279309    0.042081
# Fresh fish                                     0.007739    0.002046
# Milk                                           0.361618    0.066093
# Milo                                           0.249857   -0.003605
# Mongo and other products                       0.096757    0.148722
# Okra                                           0.164247    0.020918
# Onions                                         0.088125    0.021064
# Other beverages                                0.213546   -0.135709
# Petsay                                         0.103541   -0.217613
# Pork                                           0.105321   -0.049213
# Potato                                         0.180211    0.040708
# Processed meat like longanisa                  0.165657    0.063137
# Rice                                           0.028090   -0.075048
# Rice products                                  0.033283    0.143074
# Salt                                           0.000972    0.051073
# Sardines like youngstown, etc                 -0.083669    0.126503
# Sea weed                                       0.064980   -0.153630
# Sitao                                         -0.079047    0.008481
# Snaks like chippy, cheese curls, bread sticks  0.133006   -0.417030
# Soybean and other products                     0.079726    0.171958
# Squash                                        -0.068069    0.139939
# Sugar                                          0.081993    0.046708
# Sweet potato                                   0.002606    0.109088
# Talong                                         0.140420    0.087196
# Tomatoes                                       0.027062    0.060910
# Vetsin, MSG                                    0.085667    0.120613
# Vinegar                                       -0.048241    0.017768
#
#                                                                        \
# k                                             Males 15-20 Males 20-30
# i
# Alcoholic drinks                                 0.056806    0.163541
# Ampalaya                                         0.156066    0.183779
# Atsal                                            0.013716    0.111883
# Bagoong                                          0.049704    0.054514
# Banana                                          -0.076913    0.146409
# Beef                                            -0.030781    0.093310
# Calamansi                                        0.066229   -0.019488
# Carrots                                         -0.001757   -0.186753
# Chicken                                         -0.048649   -0.009357
# Coffee                                           0.049825    0.121861
# Coke                                            -0.047520    0.107980
# Cooking oil                                     -0.090472    0.077909
# Corn products                                   -0.262093    0.017844
# Dried fish and smoked fish                      -0.185675    0.028797
# Eggs                                             0.029464    0.096920
# Food made from flour                            -0.010039    0.085179
# Fresh fish                                      -0.048596    0.097492
# Milk                                             0.020440    0.076477
# Milo                                            -0.119769    0.085152
# Mongo and other products                         0.060551    0.039401
# Okra                                             0.142808   -0.079931
# Onions                                          -0.011198    0.116871
# Other beverages                                 -0.025750    0.063164
# Petsay                                          -0.010420   -0.020866
# Pork                                             0.044066    0.148876
# Potato                                           0.298404    0.046992
# Processed meat like longanisa                    0.141905    0.105056
# Rice                                             0.038791   -0.058511
# Rice products                                    0.058311    0.199146
# Salt                                             0.013659    0.005927
# Sardines like youngstown, etc                    0.055310    0.066545
# Sea weed                                         0.104949    0.112576
# Sitao                                           -0.065058    0.148705
# Snaks like chippy, cheese curls, bread sticks   -0.394441   -0.169736
# Soybean and other products                       0.030540    0.097378
# Squash                                           0.139355    0.198455
# Sugar                                            0.042826    0.060577
# Sweet potato                                     0.078436    0.063859
# Talong                                           0.185339    0.222147
# Tomatoes                                         0.181260    0.160089
# Vetsin, MSG                                      0.105199    0.081724
# Vinegar                                          0.090743    0.066821
#
#                                                                       \
# k                                             Males 30-50 Males 5-10
# i
# Alcoholic drinks                                 0.206622  -0.112759
# Ampalaya                                         0.195320   0.340654
# Atsal                                            0.043024   0.375754
# Bagoong                                          0.049272   0.064190
# Banana                                          -0.026650   0.196990
# Beef                                             0.192749  -0.042359
# Calamansi                                       -0.023804   0.215257
# Carrots                                         -0.081557  -0.061971
# Chicken                                         -0.019813   0.147542
# Coffee                                           0.103431   0.230042
# Coke                                             0.141227  -0.001386
# Cooking oil                                      0.060007   0.013298
# Corn products                                   -0.080419  -0.089136
# Dried fish and smoked fish                       0.046933  -0.007777
# Eggs                                             0.083571   0.367595
# Food made from flour                             0.069663   0.088443
# Fresh fish                                       0.163269   0.047843
# Milk                                             0.107197   0.103016
# Milo                                             0.052765   0.298519
# Mongo and other products                         0.084338   0.108620
# Okra                                            -0.105752  -0.057199
# Onions                                           0.167497   0.144452
# Other beverages                                  0.135693  -0.025374
# Petsay                                          -0.036197   0.248790
# Pork                                             0.132919   0.101352
# Potato                                           0.135469   0.085991
# Processed meat like longanisa                    0.234222   0.041557
# Rice                                            -0.021794   0.082861
# Rice products                                   -0.008471   0.220549
# Salt                                             0.025953   0.073484
# Sardines like youngstown, etc                    0.088010   0.046268
# Sea weed                                        -0.061884   0.019803
# Sitao                                           -0.028137   0.161367
# Snaks like chippy, cheese curls, bread sticks   -0.314448  -0.428353
# Soybean and other products                       0.080449   0.209386
# Squash                                           0.061511   0.176868
# Sugar                                            0.050249   0.149201
# Sweet potato                                     0.074655   0.242441
# Talong                                           0.194598   0.241164
# Tomatoes                                         0.053981   0.067845
# Vetsin, MSG                                      0.140858   0.048300
# Vinegar                                          0.044412   0.002100
#
#                                                                         \
# k                                             Males 50-60 Males 60-100
# i
# Alcoholic drinks                                -0.219046    -0.308157
# Ampalaya                                         0.066838    -0.013142
# Atsal                                            0.198890     0.092761
# Bagoong                                          0.159630     0.128092
# Banana                                           0.064513     0.339652
# Beef                                             0.410474     0.095913
# Calamansi                                       -0.359376    -0.005462
# Carrots                                         -0.288267     0.172051
# Chicken                                         -0.051411    -0.271361
# Coffee                                           0.164197     0.155985
# Coke                                            -0.031048    -0.024934
# Cooking oil                                     -0.120958    -0.072007
# Corn products                                    0.070563    -0.175521
# Dried fish and smoked fish                      -0.055294    -0.119848
# Eggs                                             0.147147     0.030699
# Food made from flour                             0.233261     0.383076
# Fresh fish                                       0.063806     0.034692
# Milk                                            -0.142064     0.233966
# Milo                                            -0.069992     0.049620
# Mongo and other products                        -0.233554     0.039493
# Okra                                             0.100180    -0.131503
# Onions                                           0.105558    -0.066325
# Other beverages                                  0.423710     0.260326
# Petsay                                          -0.125603     0.116855
# Pork                                            -0.031492     0.230932
# Potato                                          -0.196653     0.124944
# Processed meat like longanisa                    0.007881     0.021275
# Rice                                             0.251644     0.228520
# Rice products                                   -0.188185     0.205399
# Salt                                            -0.025002     0.136170
# Sardines like youngstown, etc                    0.151159     0.047608
# Sea weed                                         0.000190    -0.065251
# Sitao                                           -0.158684    -0.090787
# Snaks like chippy, cheese curls, bread sticks   -0.299506     0.017446
# Soybean and other products                       0.159813     0.110588
# Squash                                           0.052592     0.222905
# Sugar                                            0.115121     0.152743
# Sweet potato                                     0.494416     0.435404
# Talong                                          -0.046913    -0.033257
# Tomatoes                                        -0.086603     0.081630
# Vetsin, MSG                                      0.029660     0.024881
# Vinegar                                         -0.015316    -0.038322
#
#
# k                                             log HSize
# i
# Alcoholic drinks                               0.040358
# Ampalaya                                      -0.986332
# Atsal                                         -0.452848
# Bagoong                                        0.272523
# Banana                                        -0.825994
# Beef                                          -0.144313
# Calamansi                                     -0.304376
# Carrots                                        0.031074
# Chicken                                        0.617060
# Coffee                                        -0.390426
# Coke                                          -0.339889
# Cooking oil                                   -0.113905
# Corn products                                  0.970501
# Dried fish and smoked fish                     0.542588
# Eggs                                          -0.489300
# Food made from flour                          -0.374553
# Fresh fish                                    -0.046500
# Milk                                          -0.398009
# Milo                                          -0.377081
# Mongo and other products                       0.020566
# Okra                                          -0.206390
# Onions                                        -0.317145
# Other beverages                                0.151098
# Petsay                                         0.414256
# Pork                                           0.102189
# Potato                                        -0.489266
# Processed meat like longanisa                 -0.539346
# Rice                                           0.167124
# Rice products                                 -0.117939
# Salt                                           0.161445
# Sardines like youngstown, etc                  0.152500
# Sea weed                                      -0.019648
# Sitao                                          0.005335
# Snaks like chippy, cheese curls, bread sticks  1.634017
# Soybean and other products                    -0.582552
# Squash                                        -0.845075
# Sugar                                         -0.087382
# Sweet potato                                  -0.451376
# Talong                                        -0.427068
# Tomatoes                                      -0.455062
# Vetsin, MSG                                   -0.163041
# Vinegar                                        0.137198

# %% [markdown]
# Also the good-time constants $a_{it}$ (this captures the effects of prices)

# %%
result.a.to_dataframe().unstack('i') # bigger the number the biggerr the demand for the good
# Out:
#                       a                                                   \
# i      Alcoholic drinks Ampalaya     Atsal   Bagoong    Banana      Beef
# t    m
# 2003 1         2.667633  2.49471  1.643557  1.038494  2.579405  3.403645
#
#                                                 ...            \
# i      Calamansi   Carrots   Chicken    Coffee  ...     Sitao
# t    m                                          ...
# 2003 1  1.448823  1.484986  2.407365  2.175999  ...  1.362162
#
#                                                       \
# i      Snaks like chippy, cheese curls, bread sticks
# t    m
# 2003 1                                      0.037173
#
#                                                                               \
# i      Soybean and other products    Squash     Sugar Sweet potato    Talong
# t    m
# 2003 1                   2.044112  2.006581  2.332593     2.084173  1.778438
#
#
# i       Tomatoes Vetsin, MSG   Vinegar
# t    m
# 2003 1  1.720865    1.308317  0.357919
#
# [1 rows x 42 columns]

# %% [markdown]
# ### Second step of Estimation

# %% [markdown]
# The second step involves using Singular Value Decomposition to find
# the rank one matrix that best approximates the residuals $e_{it}^j$.
# This can be interpreted as
# $$
#     -\beta_i\log\lambda^j_t,
# $$
# where the $\log\lambda^j_t$ is the log of the marginal utility of
# expenditures (MUE) for household $j$ at time $t$, and where $\beta_i$ are
# the corresponding &ldquo;Frisch elasticities&rdquo; that tell us how much
# demand changes as the MUE falls.
#
# Estimates can also be computed as a one-liner:

# %%
result.get_beta(as_df=True) # higher the number the higher the income elasticity of the good
# Out:
# i
# Alcoholic drinks                                 0.350288
# Ampalaya                                         0.454768
# Atsal                                            0.528102
# Bagoong                                          0.256952
# Banana                                           0.525025
# Beef                                             0.420855
# Calamansi                                        0.564108
# Carrots                                          0.388565
# Chicken                                          0.482023
# Coffee                                           0.395031
# Coke                                             0.448178
# Cooking oil                                      0.437053
# Corn products                                    0.361899
# Dried fish and smoked fish                       0.309588
# Eggs                                             0.506183
# Food made from flour                             0.388270
# Fresh fish                                       0.520491
# Milk                                             0.496873
# Milo                                             0.454389
# Mongo and other products                         0.394387
# Okra                                             0.406804
# Onions                                           0.494219
# Other beverages                                  0.368522
# Petsay                                           0.610011
# Pork                                             0.434524
# Potato                                           0.221262
# Processed meat like longanisa                    0.442534
# Rice                                             0.186942
# Rice products                                    0.364453
# Salt                                             0.261200
# Sardines like youngstown, etc                    0.424168
# Sea weed                                         0.460741
# Sitao                                            0.493224
# Snaks like chippy, cheese curls, bread sticks    0.421852
# Soybean and other products                       0.374296
# Squash                                           0.419785
# Sugar                                            0.264730
# Sweet potato                                     0.244738
# Talong                                           0.518850
# Tomatoes                                         0.494378
# Vetsin, MSG                                      0.307642
# Vinegar                                          0.247343
# Name: beta, dtype: float64

# %% [markdown]
# We can also look at the results to analyze for goods that didn't have enough observations:

# %%
result.get_alpha(as_df=True)
# Out:
# i
# Alcoholic drinks                                 2.667633
# Ampalaya                                         2.494710
# Atsal                                            1.643557
# Bagoong                                          1.038494
# Banana                                           2.579405
# Beef                                             3.403645
# Calamansi                                        1.448823
# Carrots                                          1.484986
# Chicken                                          2.407365
# Coffee                                           2.175999
# Coke                                             3.167337
# Cooking oil                                      2.312384
# Corn products                                    0.851213
# Dried fish and smoked fish                       2.386023
# Eggs                                             2.704676
# Food made from flour                             3.053415
# Fresh fish                                       3.402977
# Milk                                             3.245843
# Milo                                             2.640630
# Mongo and other products                         1.880042
# Okra                                             1.496949
# Onions                                           1.838909
# Other beverages                                  1.968899
# Petsay                                           0.434452
# Pork                                             3.184386
# Potato                                           2.201080
# Processed meat like longanisa                    2.860870
# Rice                                             4.724382
# Rice products                                    2.000139
# Salt                                             0.577709
# Sardines like youngstown, etc                    1.969957
# Sea weed                                         1.757412
# Sitao                                            1.362162
# Snaks like chippy, cheese curls, bread sticks    0.037173
# Soybean and other products                       2.044112
# Squash                                           2.006581
# Sugar                                            2.332593
# Sweet potato                                     2.084173
# Talong                                           1.778438
# Tomatoes                                         1.720865
# Vetsin, MSG                                      1.308317
# Vinegar                                          0.357919
# Name: alpha, dtype: float64

# %% [markdown]
# ### Assessment of Fit

# %% [markdown]
# Comparing total expenditures predicted by the
# model we&rsquo;ve estimated with actual total expenditures:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.cm as cm

xbar = np.exp(result.y).sum(['m','i']).to_dataframe('xbar').replace(0,np.nan).squeeze()
xhat = result.get_predicted_expenditures().sum(['m','i']).to_dataframe('xhat').replace(0,np.nan).squeeze()

# Make dataframe of actual & predicted
df = pd.DataFrame({'Actual':np.log(xbar),'Predicted':np.log(xhat)})

df.plot.scatter(x='Predicted',y='Actual')

# Add 45 degree line
v = plt.axis()
vmin = np.max([v[0],v[2]])
vmax = np.max([v[1],v[3]])
plt.plot([vmin,vmax],[vmin,vmax]);

# %% [markdown]
# ### Saving Result

# %%
# again, uncomment if necessary
# !pip install h5netcdf

# %%
result.to_dataset('icrisat.ds')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-982bdd3912d6> in <module>
# ----> 1 result.to_dataset('icrisat.ds')
#
# /opt/conda/lib/python3.8/site-packages/cfe/result.py in to_dataset(self, fn)
#     581
#     582         if fn is not None:
# --> 583             D.to_netcdf(fn,engine='h5netcdf',invalid_netcdf=True)
#     584
#     585         return D
#
# /opt/conda/lib/python3.8/site-packages/xarray/core/dataset.py in to_netcdf(self, path, mode, format, group, engine, encoding, unlimited_dims, compute, invalid_netcdf)
#    1642         from ..backends.api import to_netcdf
#    1643
# -> 1644         return to_netcdf(
#    1645             self,
#    1646             path,
#
# /opt/conda/lib/python3.8/site-packages/xarray/backends/api.py in to_netcdf(dataset, path_or_file, mode, format, group, engine, encoding, unlimited_dims, compute, multifile, invalid_netcdf)
#    1092                 "unrecognized option 'invalid_netcdf' for engine %s" % engine
#    1093             )
# -> 1094     store = store_open(target, mode, format, group, **kwargs)
#    1095
#    1096     if unlimited_dims is None:
#
# /opt/conda/lib/python3.8/site-packages/xarray/backends/h5netcdf_.py in open(cls, filename, mode, format, group, lock, autoclose, invalid_netcdf, phony_dims)
#     122         phony_dims=None,
#     123     ):
# --> 124         import h5netcdf
#     125
#     126         if isinstance(filename, bytes):
#
# ModuleNotFoundError: No module named 'h5netcdf'
